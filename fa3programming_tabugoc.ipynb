# %% [markdown]
# <a href="https://colab.research.google.com/github/MariTabugoc/fa3programming/blob/main/fa3programming_tabugoc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#fa3prog1

name = input("What is your name? ")
age = input("What is your age? ")
course = input("what is your course? ")


print("Student Information")
print("Name:", name)
print("Age:", age)
print("Course:", course)

# %%
#fa3prog2

score = int(input("Enter your score: "))

if score > 74:
    print("Passed")
else:
    print("Failed")

# %%
#fa3prog3

name = input("Enter your name: ")
score = int(input("Enter your score: "))

if score > 89:
    grade = "A"
elif score > 79:
    grade = "B"
elif score > 69:
    grade = "C"
else:
    grade = "F"

print("Grade:", grade)
